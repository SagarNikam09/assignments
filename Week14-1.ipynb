# %% [markdown]
# # Q1]
#
# The wine quality data set includes the following key features:
# 1. Fixed Acidity: Affects the tartness and freshness of wine.
# 2. Volatile Acidity: High levels can lead to an unpleasant vinegar taste.
# 3. Citric Acid: Adds freshness and flavor.
# 4. Residual Sugar: Higher levels make the wine sweeter.
# 5. Chlorides: Higher levels can lead to a salty taste.
# 6. Free Sulfur Dioxide: Prevents microbial growth and oxidation.
# 7. Total Sulfur Dioxide: Indicates preservative content.
# 8. Density: Related to alcohol and sugar content.
# 9. pH: Affects the taste and microbial stability.
# 10. Sulphates: Adds to the wine’s sulfur dioxide content.
# 11. Alcohol: Higher levels can enhance the quality of wine.
# Each feature is important as they collectively contribute to the taste, aroma, and overall quality of the wine.

# %% [markdown]
# #Q2]
#
# Imputation Techniques:
# 1. Mean/Median Imputation:
#    - Advantages: Simple, quick.
#    - Disadvantages: Can distort data distribution.
# 2. Mode Imputation:
#    - Advantages: Good for categorical data.
#    - Disadvantages: Less effective for continuous data.
# 3. K-Nearest Neighbors (KNN):
#    - Advantages: Considers data correlations.
#    - Disadvantages: Computationally expensive.
# 4. Regression Imputation:
#    - Advantages: Maintains relationships among variables.
#    - Disadvantages: Complex, assumes linear relationships.

# %% [markdown]
# #3]
#
# Key factors:
# - Study Hours: Directly correlated with performance.
# - Socioeconomic Status: Influences access to resources.
# - Parental Support: Encourages better academic outcomes.
# - School Environment: Affects motivation and engagement.
# Statistical Techniques:
# - Correlation Analysis: Identifies relationships between factors.
# - Regression Analysis: Predicts performance based on variables.
# - ANOVA: Compares performance across different groups.
# - Principal Component Analysis (PCA): Reduces dimensionality while preserving variance.

# %% [markdown]
# #4]
# Process:
# 1. Feature Selection: Choose relevant variables (e.g., study hours, attendance).
# 2. Transformation:
#    - Normalization: Scale numerical features to a similar range.
#    - Encoding: Convert categorical variables into numerical form (e.g., one-hot encoding).
# Steps:
# 1. Identify key variables: Based on domain knowledge.
# 2. Transform data: Apply scaling, encoding, and normalization.
# 3. Create interaction terms: Combine features to capture relationships.

# %%
#Q5]
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load the Data
df = pd.read_csv('winequality-red.csv')

# Visualize Distributions
df.hist(bins=30, figsize=(15, 10))
plt.show()

# Identify Non-Normal Features
sns.boxplot(data=df)
plt.show()

# Apply Log Transformation to a Non-Normal Feature Example
df['fixed acidity'] = df['fixed acidity'].apply(lambda x: np.log1p(x))

# Check Transformation
sns.histplot(df['fixed acidity'])
plt.show()
# Out:
# C:\Users\Sagar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Q6]
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Standardize the features
features = df.drop('quality', axis=1)
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Perform PCA
pca = PCA().fit(features_scaled)
explained_variance = np.cumsum(pca.explained_variance_ratio_)
n_components = np.argmax(explained_variance >= 0.90) + 1

# Minimum number of principal components to explain 90% variance
print(f"Minimum number of principal components to explain 90% variance: {n_components}")
# Out:
# Minimum number of principal components to explain 90% variance: 7
